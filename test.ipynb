# %%
import pandas as pd

# %%
clinical_trials = pd.read_csv("data/clinical_trials.csv", header=0, sep=',')
clinical_trials.head(10)
# Out:
#             id                                   scientific_title  \
# 0  NCT01967433  Use of Diphenhydramine as an Adjunctive Sedati...
# 1  NCT04189588  Phase 2 Study IV QUZYTTIR™ (Cetirizine Hydroch...
# 2  NCT04237090
# 3  NCT04237091  Feasibility of a Randomized Controlled Clinica...
# 4  NCT04153396  Preemptive Infiltration With Betamethasone and...
# 5  NCT03490942  Glucagon Infusion in T1D Patients With Recurre...
# 6          NaN  Glucagon Infusion in T1D Patients With Recurre...
# 7  NCT04188184  Tranexamic Acid Versus Epinephrine During Expl...
#
#              date                               journal
# 0  1 January 2020          Journal of emergency nursing
# 1  1 January 2020          Journal of emergency nursing
# 2  1 January 2020          Journal of emergency nursing
# 3  1 January 2020          Journal of emergency nursing
# 4  1 January 2020     Hôpitaux Universitaires de Genève
# 5      25/05/2020                                   NaN
# ...

# %%
drugs = pd.read_csv("data/drugs.csv", header=0, sep=',')
drugs.head(10)
# Out:
#    atccode             drug
# 0    A04AD  DIPHENHYDRAMINE
# 1    S03AA     TETRACYCLINE
# 2    V03AB          ETHANOL
# 3    A03BA         ATROPINE
# 4    A01AD      EPINEPHRINE
# 5  6302001     ISOPRENALINE
# 6    R01AD    BETAMETHASONE

# %%
pubmed = pd.read_csv("data/pubmed.csv", header=0, sep=',')
pubmed.head(10)
# Out:
#    id                                              title        date  \
# 0   1  A 44-year-old man with erythema of the face di...  01/01/2019
# 1   2  An evaluation of benadryl, pyribenzamine, and ...  01/01/2019
# 2   3  Diphenhydramine hydrochloride helps symptoms o...  02/01/2019
# 3   4  Tetracycline Resistance Patterns of Lactobacil...  01/01/2020
# 4   5  Appositional Tetracycline bone formation rates...  02/01/2020
# 5   6  Rapid reacquisition of contextual fear followi...  2020-01-01
# 6   7  The High Cost of Epinephrine Autoinjectors and...  01/02/2020
# 7   8  Time to epinephrine treatment is associated wi...  01/03/2020
#
#                                              journal
# 0                       Journal of emergency nursing
# 1                       Journal of emergency nursing
# 2                          The Journal of pediatrics
# 3                         Journal of food protection
# 4            American journal of veterinary research
# ...

# %%
print(pubmed['date'])
# Out:
# 0    01/01/2019
# 1    01/01/2019
# 2    02/01/2019
# 3    01/01/2020
# 4    02/01/2020
# 5    2020-01-01
# 6    01/02/2020
# 7    01/03/2020
# Name: date, dtype: object

# %%
# Function to parse and reformat dates
def parse_and_reformat(date_str):
    try:
        # Try to parse the date using multiple formats
        date_formats = ['%d/%m/%Y', '%d-%m-%Y', '%Y-%m-%d', '%d %B %Y']
        for fmt in date_formats:
            try:
                parsed_date = pd.to_datetime(date_str, format=fmt)
                # Reformat the parsed date to the desired format
                reformatted_date = parsed_date.strftime('%d/%m/%Y')
                return reformatted_date
            except ValueError:
                pass  # Continue to the next format if the current one fails

        # If none of the formats match, return None
        return None
    except Exception as e:
        print(f"Error processing date {date_str}: {e}")
        return None

# %%
# Apply the function to the 'date' column
pubmed['date'] = pubmed['date'].apply(parse_and_reformat)

# Print the DataFrame with reformatted dates
pubmed.head(20)
# Out:
#    id                                              title        date  \
# 0   1  A 44-year-old man with erythema of the face di...  01/01/2019
# 1   2  An evaluation of benadryl, pyribenzamine, and ...  01/01/2019
# 2   3  Diphenhydramine hydrochloride helps symptoms o...  02/01/2019
# 3   4  Tetracycline Resistance Patterns of Lactobacil...  01/01/2020
# 4   5  Appositional Tetracycline bone formation rates...  02/01/2020
# 5   6  Rapid reacquisition of contextual fear followi...  01/01/2020
# 6   7  The High Cost of Epinephrine Autoinjectors and...  01/02/2020
# 7   8  Time to epinephrine treatment is associated wi...  01/03/2020
#
#                                              journal
# 0                       Journal of emergency nursing
# 1                       Journal of emergency nursing
# 2                          The Journal of pediatrics
# 3                         Journal of food protection
# 4            American journal of veterinary research
# ...

# %%
clinical_trials['date'] = clinical_trials['date'].apply(parse_and_reformat)

# %%
clinical_trials.head(10)
# Out:
#             id                                   scientific_title        date  \
# 0  NCT01967433  Use of Diphenhydramine as an Adjunctive Sedati...  01/01/2020
# 1  NCT04189588  Phase 2 Study IV QUZYTTIR™ (Cetirizine Hydroch...  01/01/2020
# 2  NCT04237090                                                     01/01/2020
# 3  NCT04237091  Feasibility of a Randomized Controlled Clinica...  01/01/2020
# 4  NCT04153396  Preemptive Infiltration With Betamethasone and...  01/01/2020
# 5  NCT03490942  Glucagon Infusion in T1D Patients With Recurre...  25/05/2020
# 6          NaN  Glucagon Infusion in T1D Patients With Recurre...  25/05/2020
# 7  NCT04188184  Tranexamic Acid Versus Epinephrine During Expl...  27/04/2020
#
#                                 journal
# 0          Journal of emergency nursing
# 1          Journal of emergency nursing
# 2          Journal of emergency nursing
# 3          Journal of emergency nursing
# 4     Hôpitaux Universitaires de Genève
# ...

# %%
clinical_trials.fillna('')
# Out:
#             id                                   scientific_title        date  \
# 0  NCT01967433  Use of Diphenhydramine as an Adjunctive Sedati...  01/01/2020
# 1  NCT04189588  Phase 2 Study IV QUZYTTIR™ (Cetirizine Hydroch...  01/01/2020
# 2  NCT04237090                                                     01/01/2020
# 3  NCT04237091  Feasibility of a Randomized Controlled Clinica...  01/01/2020
# 4  NCT04153396  Preemptive Infiltration With Betamethasone and...  01/01/2020
# 5  NCT03490942  Glucagon Infusion in T1D Patients With Recurre...  25/05/2020
# 6               Glucagon Infusion in T1D Patients With Recurre...  25/05/2020
# 7  NCT04188184  Tranexamic Acid Versus Epinephrine During Expl...  27/04/2020
#
#                                 journal
# 0          Journal of emergency nursing
# 1          Journal of emergency nursing
# 2          Journal of emergency nursing
# 3          Journal of emergency nursing
# 4     Hôpitaux Universitaires de Genève
# 5
# ...

# %%
pubmed.fillna('')
# Out:
#    id                                              title        date  \
# 0   1  A 44-year-old man with erythema of the face di...  01/01/2019
# 1   2  An evaluation of benadryl, pyribenzamine, and ...  01/01/2019
# 2   3  Diphenhydramine hydrochloride helps symptoms o...  02/01/2019
# 3   4  Tetracycline Resistance Patterns of Lactobacil...  01/01/2020
# 4   5  Appositional Tetracycline bone formation rates...  02/01/2020
# 5   6  Rapid reacquisition of contextual fear followi...  01/01/2020
# 6   7  The High Cost of Epinephrine Autoinjectors and...  01/02/2020
# 7   8  Time to epinephrine treatment is associated wi...  01/03/2020
#
#                                              journal
# 0                       Journal of emergency nursing
# 1                       Journal of emergency nursing
# 2                          The Journal of pediatrics
# 3                         Journal of food protection
# 4            American journal of veterinary research
# ...

# %%
drugs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   atccode  7 non-null      object
#  1   drug     7 non-null      object
# dtypes: object(2)
# memory usage: 244.0+ bytes

# %%
drugs.fillna('')
# Out:
#    atccode             drug
# 0    A04AD  DIPHENHYDRAMINE
# 1    S03AA     TETRACYCLINE
# 2    V03AB          ETHANOL
# 3    A03BA         ATROPINE
# 4    A01AD      EPINEPHRINE
# 5  6302001     ISOPRENALINE
# 6    R01AD    BETAMETHASONE

# %%
pubmed.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
if pubmed.duplicated().any() == True:
    pubmed.drop_duplicates(inplace=True)

# %%
clinical_trials.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
clinical_trials['scientific_title'] = clinical_trials['scientific_title'].str.lower()

# %%
clinical_trials['journal']= clinical_trials['journal'].str.lower()

# %%
clinical_trials['id']= clinical_trials['id'].str.lower()

# %%
clinical_trials['date']= clinical_trials['date'].str.lower()

# %%
clinical_trials = clinical_trials.applymap(lambda x: x.lower() if isinstance(x, str) else x)
# Out:
# C:\Users\SamarMAMI\AppData\Local\Temp\ipykernel_18084\2607625519.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   clinical_trials = clinical_trials.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
drugs = drugs.applymap(lambda x: x.lower() if isinstance(x, str) else x)
# Out:
# C:\Users\SamarMAMI\AppData\Local\Temp\ipykernel_18084\528961250.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   drugs = drugs.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
pubmed = pubmed.applymap(lambda x: x.lower() if isinstance(x, str) else x)
# Out:
# C:\Users\SamarMAMI\AppData\Local\Temp\ipykernel_18084\2922442821.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   pubmed = pubmed.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
clinical_trials['scientific_title'] = clinical_trials['scientific_title'].str.replace('[^a-zA-Z0-9 ]', '', regex=True)

# %%
pubmed['title'] = pubmed['title'].str.replace('[^a-zA-Z0-9 ]', '', regex=True)

# %%
clinical_trials.rename(columns = {'scientific_title':'title'}, inplace = True)

# %%
def rename_columns(df, column, new_column):
    df.rename(columns={f'{column}': new_column}, inplace=True)

# %%
rename_columns(clinical_trials,'scientific_title','title')

# %%
clinical_trials.head(5)
# Out:
#             id                                   scientific_title        date  \
# 0  nct01967433  use of diphenhydramine as an adjunctive sedati...  01/01/2020
# 1  nct04189588  phase 2 study iv quzyttir™ (cetirizine hydroch...  01/01/2020
# 2  nct04237090                                                     01/01/2020
# 3  nct04237091  feasibility of a randomized controlled clinica...  01/01/2020
# 4  nct04153396  preemptive infiltration with betamethasone and...  01/01/2020
#
#                              journal
# 0       journal of emergency nursing
# 1       journal of emergency nursing
# 2       journal of emergency nursing
# 3       journal of emergency nursing
# 4  hôpitaux universitaires de genève

# %%
pubmed.head(5)
# Out:
#    id                                              title        date  \
# 0   1  a 44yearold man with erythema of the face diph...  01/01/2019
# 1   2  an evaluation of benadryl pyribenzamine and ot...  01/01/2019
# 2   3  diphenhydramine hydrochloride helps symptoms o...  02/01/2019
# 3   4  tetracycline resistance patterns of lactobacil...  01/01/2020
# 4   5  appositional tetracycline bone formation rates...  02/01/2020
#
#                                    journal
# 0             journal of emergency nursing
# 1             journal of emergency nursing
# 2                the journal of pediatrics
# 3               journal of food protection
# 4  american journal of veterinary research

# %%
drugs.head(10)
# Out:
#    atccode             drug
# 0    a04ad  diphenhydramine
# 1    s03aa     tetracycline
# 2    v03ab          ethanol
# 3    a03ba         atropine
# 4    a01ad      epinephrine
# 5  6302001     isoprenaline
# 6    r01ad    betamethasone

# %%
def find_drug_name(df_reference, referance_name_column, df_search_in, title_search_in_column):
    df_found = pd.DataFrame(columns=['drug', 'referenced_in', 'date_mention', 'journal'])
    for drug in df_reference[f'{referance_name_column}']:
        for title in df_search_in[f'{title_search_in_column}']:
            if drug in title:
                print("Searching for " f'{drug}',"...")
                index = df_search_in[df_search_in[f'{title_search_in_column}'] == title].index[0]
                # Append the data to df_found
                row = [drug, title, df_search_in.loc[index, 'date'], df_search_in.loc[index, 'journal']]
                df_found.loc[len(df_found)] = row
    return df_found

# %%
df_found_1 = pd.DataFrame(columns=['drug', 'title_clinical_test', 'date_clinical_test', 'journal'])
for drug in drugs['drug']:
    for title in clinical_trials['scientific_title']:
        if drug in title:
            index = clinical_trials[clinical_trials['scientific_title'] == title].index[0]
            # Append the data to df_found
            row = [drug, title, clinical_trials.loc[index, 'date'], clinical_trials.loc[index, 'journal']]
            df_found_1.loc[len(df_found_1)] = row
df_found_1.head(10)
# Out:
#               drug                                title_clinical_test  \
# 0  diphenhydramine  use of diphenhydramine as an adjunctive sedati...
# 1  diphenhydramine  phase 2 study iv quzyttir™ (cetirizine hydroch...
# 2  diphenhydramine  feasibility of a randomized controlled clinica...
# 3      epinephrine  tranexamic acid versus epinephrine during expl...
# 4    betamethasone  preemptive infiltration with betamethasone and...
#
#   date_clinical_test                               journal
# 0         01/01/2020          journal of emergency nursing
# 1         01/01/2020          journal of emergency nursing
# 2         01/01/2020          journal of emergency nursing
# 3         27/04/2020  journal of emergency nursing\xc3\x28
# 4         01/01/2020     hôpitaux universitaires de genève

# %%
df_found_2 = pd.DataFrame(columns=['drug', 'title_pubmed', 'date_pubmed', 'journal'])
for drug in drugs['drug']:
    for title in pubmed['title']:
        if drug in title:
            index = pubmed[pubmed['title'] == title].index[0]
            # Append the data to df_found
            row = [drug, title, pubmed.loc[date_index, 'date'], pubmed.loc[date_index, 'journal']]
            df_found_2.loc[len(df_found_2)] = row
df_found_2.head(10)
# Out:
#               drug                                       title_pubmed  \
# 0  diphenhydramine  a 44yearold man with erythema of the face diph...
# 1  diphenhydramine  an evaluation of benadryl pyribenzamine and ot...
# 2  diphenhydramine  diphenhydramine hydrochloride helps symptoms o...
# 3     tetracycline  tetracycline resistance patterns of lactobacil...
# 4     tetracycline  appositional tetracycline bone formation rates...
# 5     tetracycline  rapid reacquisition of contextual fear followi...
# 6          ethanol  rapid reacquisition of contextual fear followi...
# 7      epinephrine  the high cost of epinephrine autoinjectors and...
# 8      epinephrine  time to epinephrine treatment is associated wi...
#
#   date_pubmed                                            journal
# 0  01/03/2020  the journal of allergy and clinical immunology...
# 1  01/03/2020  the journal of allergy and clinical immunology...
# 2  01/03/2020  the journal of allergy and clinical immunology...
# ...

# %%
final_df = pd.merge(df_found_1, df_found_2, on="drug")

# %%
final_df.head()
# Out:
#               drug                                title_clinical_test  \
# 0  diphenhydramine  use of diphenhydramine as an adjunctive sedati...
# 1  diphenhydramine  use of diphenhydramine as an adjunctive sedati...
# 2  diphenhydramine  use of diphenhydramine as an adjunctive sedati...
# 3  diphenhydramine  phase 2 study iv quzyttir™ (cetirizine hydroch...
# 4  diphenhydramine  phase 2 study iv quzyttir™ (cetirizine hydroch...
#
#   date_clinical_test                     journal_x  \
# 0         01/01/2020  journal of emergency nursing
# 1         01/01/2020  journal of emergency nursing
# 2         01/01/2020  journal of emergency nursing
# 3         01/01/2020  journal of emergency nursing
# 4         01/01/2020  journal of emergency nursing
#
#                                         title_pubmed date_pubmed  \
# 0  a 44yearold man with erythema of the face diph...  01/03/2020
# 1  an evaluation of benadryl pyribenzamine and ot...  01/03/2020
# ...

# %%
json = final_df.to_json() 
  
# Print json object 
print(json)
# Out:
# {"drug":{"0":"diphenhydramine","1":"diphenhydramine","2":"diphenhydramine","3":"diphenhydramine","4":"diphenhydramine","5":"diphenhydramine","6":"diphenhydramine","7":"diphenhydramine","8":"diphenhydramine","9":"epinephrine","10":"epinephrine"},"title_clinical_test":{"0":"use of diphenhydramine as an adjunctive sedative for colonoscopy in patients chronically on opioids","1":"use of diphenhydramine as an adjunctive sedative for colonoscopy in patients chronically on opioids","2":"use of diphenhydramine as an adjunctive sedative for colonoscopy in patients chronically on opioids","3":"phase 2 study iv quzyttir\u2122 (cetirizine hydrochloride injection) vs v diphenhydramine","4":"phase 2 study iv quzyttir\u2122 (cetirizine hydrochloride injection) vs v diphenhydramine","5":"phase 2 study iv quzyttir\u2122 (cetirizine hydrochloride injection) vs v diphenhydramine","6":"feasibility of a randomized controlled clinical trial comparing the use of cetirizine to replace diphenhydramine in the
# ...

# %%
def find_drug_name(df_reference, referance_name_column, df_search_in, title_search_in_column):
    df_found = pd.DataFrame(columns=['drug', 'referenced_in', 'date_mention'])
    for drug in df_reference[f'{referance_name_column}']:
        for title in df_search_in[f'{title_search_in_column}']:
            if drug in title:
                print("Searching for " f'{drug}',"...")
                date_index = df_search_in[df_search_in[f'{title_search_in_column}'] == title].index[0]
                # Append the data to df_found
                row = [drug, title, df_search_in.loc[date_index, 'date']]
                df_found.loc[len(df_found)] = row
    return df_found

# %%
df_clinical_trials_search = find_drug_name(drugs, 'drug', clinical_trials, 'scientific_title')
df_clinical_trials_search.head(5)
# Out:
# Searching for diphenhydramine ...
# Searching for diphenhydramine ...
# Searching for diphenhydramine ...
# Searching for epinephrine ...
# Searching for betamethasone ...
#               drug                                      referenced_in  \
# 0  diphenhydramine  use of diphenhydramine as an adjunctive sedati...
# 1  diphenhydramine  phase 2 study iv quzyttir™ (cetirizine hydroch...
# 2  diphenhydramine  feasibility of a randomized controlled clinica...
# 3      epinephrine  tranexamic acid versus epinephrine during expl...
# 4    betamethasone  preemptive infiltration with betamethasone and...
#
#   date_mention                               journal
# 0   01/01/2020          journal of emergency nursing
# 1   01/01/2020          journal of emergency nursing
# 2   01/01/2020          journal of emergency nursing
# 3   27/04/2020  journal of emergency nursing\xc3\x28
# 4   01/01/2020     hôpitaux universitaires de genève

# %%
df_pubmed_search = find_drug_name(drugs, 'drug', pubmed, 'title')
df_pubmed_search.head(5)
# Out:
# Searching for diphenhydramine ...
# Searching for diphenhydramine ...
# Searching for diphenhydramine ...
# Searching for tetracycline ...
# Searching for tetracycline ...
# Searching for tetracycline ...
# Searching for ethanol ...
# Searching for epinephrine ...
# Searching for epinephrine ...
#               drug                                      referenced_in  \
# 0  diphenhydramine  a 44yearold man with erythema of the face diph...
# 1  diphenhydramine  an evaluation of benadryl pyribenzamine and ot...
# 2  diphenhydramine  diphenhydramine hydrochloride helps symptoms o...
# 3     tetracycline  tetracycline resistance patterns of lactobacil...
# 4     tetracycline  appositional tetracycline bone formation rates...
#
#   date_mention                                  journal
# 0   01/01/2019             journal of emergency nursing
# 1   01/01/2019             journal of emergency nursing
# 2   02/01/2019                the journal of pediatrics
# ...

# %%
drugs.map(lambda x: x.lower() if isinstance(x, str) else x)
# Out:
#    atccode             drug
# 0    a04ad  diphenhydramine
# 1    s03aa     tetracycline
# 2    v03ab          ethanol
# 3    a03ba         atropine
# 4    a01ad      epinephrine
# 5  6302001     isoprenaline
# 6    r01ad    betamethasone

# %%
drugs
# Out:
#    atccode             drug
# 0    A04AD  DIPHENHYDRAMINE
# 1    S03AA     TETRACYCLINE
# 2    V03AB          ETHANOL
# 3    A03BA         ATROPINE
# 4    A01AD      EPINEPHRINE
# 5  6302001     ISOPRENALINE
# 6    R01AD    BETAMETHASONE
